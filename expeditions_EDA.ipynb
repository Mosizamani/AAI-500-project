# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # `expeditions.csv`:

# %%
expeditions_data = pd.read_csv('data/expeditions.csv')

# %% [markdown]
# `peak_id` : ID of a peak

# %%
peak_id = expeditions_data['peak_id']
print(peak_id.value_counts())           # How many of each unique peak_id occurs?
peak_id.describe()                      # Prints the total number of rows, how many unique peak_ids there are, 
                                        # which variable occurs the most (and how many times)
# Out:
# peak_id
# EVER    2155
# AMAD    1429
# CHOY    1341
# MANA     677
# LHOT     430
#         ...
# KAPT       1
# DZAN       1
# NGOR       1
# FIRW       1
# LNAK       1
# Name: count, Length: 385, dtype: int64
# count     10494
# unique      385
# top        EVER
# freq       2155
# Name: peak_id, dtype: object

# %% [markdown]
# `peak_name`: Peak Name

# %%
peak_name = expeditions_data['peak_name']
print(peak_name.value_counts())             # How many of each unique peak_name occurs?
peak_name.describe()                        # Prints the total number of rows, how many unique peak_names there are, 
                                            # which variable occurs the most (and how many times)
# Out:
# peak_name
# Everest          2155
# Ama Dablam       1429
# Cho Oyu          1341
# Manaslu           677
# Lhotse            430
#                  ...
# Kaptang             1
# Dzanye              1
# Nagoru              1
# Firnkopf West       1
# Lhonak              1
# Name: count, Length: 385, dtype: int64
# count       10494
# unique        385
# top       Everest
# freq         2155
# Name: peak_name, dtype: object

# %% [markdown]
# `nationality`: Thr principle nationality of the expedition (main nationality)

# %%
nationality = expeditions_data['nationality']
print(nationality.value_counts())             # How many of each unique nationality occurs?
nationality.describe()                        # Prints the total number of rows, how many unique nationalities there are, 
                                              # which variable occurs the most (and how many times)
# Out:
# nationality
# USA                1167
# Japan              1040
# UK                  930
# France              797
# Spain               707
#                    ...
# Hong Kong             1
# Sri Lanka             1
# Cyprus                1
# Macedonia             1
# Kyrgyz Republic       1
# Name: count, Length: 97, dtype: int64
# count     10494
# unique       97
# top         USA
# freq       1167
# Name: nationality, dtype: object

# %% [markdown]
# `year`: Expedition year

# %%
year = expeditions_data['year']
print(year.value_counts())          # How many of each unique year occurs?
year.describe()                     # Prints the total number of rows, mean, standard deviation,
                                    # minimum, maximum, lower quartile, upper quartile, and median
# years = []                          # List of Unique years
# for i in year:
#     if i in years:
#         continue
#     elif i not in years:
#         years.append(i)
# print(len(years))
# Out:
# year
# 2009    420
# 2011    417
# 2012    412
# 2006    411
# 2010    406
#        ...
# 1922      1
# 1905      1
# 1921      1
# 1931      1
# 1940      1
# Name: count, Length: 93, dtype: int64
# count    10494.000000
# mean      2001.531065
# std         14.755142
# min       1905.000000
# 25%       1994.000000
# 50%       2006.000000
# 75%       2012.000000
# max       2020.000000
# Name: year, dtype: float64

# %% [markdown]
# `season`: Expedition season

# %%
season = expeditions_data['season']
print(season.value_counts())            # How many of each unique season occurs?
season.describe()                       # Prints the total number of rows, how many unique seasons there are, 
                                        # which variable occurs the most (and how many times)
# Out:
# season
# Autumn    5209
# Spring    4860
# Winter     317
# Summer     106
# All          2
# Name: count, dtype: int64
# count      10494
# unique         5
# top       Autumn
# freq        5209
# Name: season, dtype: object

# %% [markdown]
# `host_cntr`: Country from which ascent has begun

# %%
host_cntr = expeditions_data['host_cntr']
print(host_cntr.value_counts())             # How many of each unique host_cntr occurs?
host_cntr.describe()                        # Prints the total number of rows, how many unique host_cntrs there are, 
                                            # which variable occurs the most (and how many times)
# Out:
# host_cntr
# Nepal      8204
# China      2221
# India        67
# Unknown       2
# Name: count, dtype: int64
# count     10494
# unique        4
# top       Nepal
# freq       8204
# Name: host_cntr, dtype: object

# %% [markdown]
# `other_cntrs`: Countries that took part in the expedition (members nationality)

# %%
other_cntr = expeditions_data['other_cntrs']
print(other_cntr.value_counts())            # How many of each unique other_cntr occurs?
other_cntr.describe()                       # Prints the total number of rows, how many unique other_cntrs there are, 
                                            # which variable occurs the most (and how many times)
# Out:
# other_cntrs
# USA                                                  182
# UK                                                   149
# Switzerland                                          143
# Germany                                              142
# France                                                99
#                                                     ...
# Austria, Germany, Switzerland, UK                      1
# Australia, Germany, Canada, Czech Republic, UK         1
# Australia, Japan, Switzerland, USA                     1
# Finland, Ireland, Japan, Nepal, Netherlands, Peru      1
# Germany, Kosovo                                        1
# Name: count, Length: 1239, dtype: int64
# count     3508
# unique    1239
# top        USA
# freq       182
# Name: other_cntrs, dtype: object

# %% [markdown]
# `sponsor`: Expedition sponsor
# [Are they climbing solo or with an organization?]

# %%
sponsor = expeditions_data['sponsor']
print(sponsor.value_counts())           # How many of each unique sponsor occurs?
sponsor.describe()                      # Prints the total number of rows, how many unique sponsors there are, 
                                        # which variable occurs the most (and how many times)
# Out:
# sponsor
# Independent climber                                62
# Independent climber on Everest                     24
# Independent team                                   16
# Ama Dablam Expedition                              15
# Independent climber on Cho Oyu                     15
#                                                    ..
# Holy Mountain Adventure Cho Oyu Expedition 2016     1
# Czech Cho Oyu Expedition 2016                       1
# French Cho Oyu Expedition 2015                      1
# DAV Schwaben Cho Oyu Expedition 2016                1
# Yaupa First Ascent 2017                             1
# Name: count, Length: 8316, dtype: int64
# count                    9677
# unique                   8316
# top       Independent climber
# freq                       62
# Name: sponsor, dtype: object

# %% [markdown]
# `leaders`: Leader/leaders of the expedition

# %%
leader = expeditions_data['leaders']
print(leader.value_counts())            # How many of each unique leader occurs?
leader.describe()                       # Prints the total number of rows, how many unique leaders there are, 
                                        # which variable occurs the most (and how many times)
# Out:
# leaders
# Paulo Grobel                61
# Russell Brice               49
# Dan Mazur                   46
# Henry Todd                  44
# Arnold Coster               35
#                             ..
# Go Mi-Sun                    1
# Davide Arrigo                1
# Toshio Abe                   1
# Tomio Chiba                  1
# Francesc Dalmeses Cunill     1
# Name: count, Length: 5648, dtype: int64
# count            10470
# unique            5648
# top       Paulo Grobel
# freq                61
# Name: leaders, dtype: object

# %% [markdown]
# `rte_1_name`: The first route name (similar for the rest features with the same prefix)

# %%
rte_1_name = expeditions_data['rte_1_name']
print(rte_1_name.value_counts())            # How many of each unique rte_1_name occurs?
rte_1_name.describe()                       # Prints the total number of rows, how many unique rte_1_names there are, 
                                            # which variable occurs the most (and how many times)
# Out:
# rte_1_name
# SW Ridge                                       1530
# S Col-SE Ridge                                 1138
# NW side                                        1080
# NE Face                                         702
# N Col-NE Ridge                                  672
#                                                ...
# N Face (Great Couloir) (to 8000m)                 1
# E Face-S Col (Venables rte)                       1
# N Col-N Ridge-N Face up; Great Couloir down       1
# Couloir on E side of N Ridge (to 8000m)           1
# S Face of WSW Ridge                               1
# Name: count, Length: 1229, dtype: int64
# count        10337
# unique        1229
# top       SW Ridge
# freq          1530
# Name: rte_1_name, dtype: object

# %% [markdown]
# `rte_2_name`: The second route name

# %%
rte_2_name = expeditions_data['rte_2_name']
print(rte_2_name.value_counts())            # How many of each unique rte_2_name occurs?
rte_2_name.describe()                       # Prints the total number of rows, how many unique rte_2_names there are, 
                                            # which variable occurs the most (and how many times)
# Out:
# rte_2_name
# S Col-SE Ridge                                     8
# N Face                                             7
# NE Ridge                                           6
# SW Ridge                                           6
# NW side                                            6
#                                                   ..
# N Col                                              1
# N Face (left of Great Couloir) (to 7315m)          1
# Geneva Spur-SE Ridge (to 7800m)                    1
# N Face (Japanese Couloir) (to 7710m)               1
# SE Ridge up; N Ridge-Cntrl/Main/South Smts down    1
# Name: count, Length: 253, dtype: int64
# count                313
# unique               253
# top       S Col-SE Ridge
# freq                   8
# Name: rte_2_name, dtype: object

# %% [markdown]
# `rte_3_name`: The third route name

# %%
rte_3_name = expeditions_data['rte_3_name']
print(rte_3_name.value_counts())            # How many of each unique rte_3_name occurs?
rte_3_name.describe()                       # Prints the total number of rows, how many unique rte_3_names there are, 
                                            # which variable occurs the most (and how many times)
# Out:
# rte_3_name
# NW Ridge (to 7200m)                                 1
# W Ridge-W Face from S                               1
# W Face (to 7000m)                                   1
# E Face (to 5200m)                                   1
# SW Ridge                                            1
# E Ridge up; SE Face down                            1
# NE Face (to 7500m)                                  1
# Makalu La-NW Ridge                                  1
# W Face (to 6550m)                                   1
# NW side (to 7100m)                                  1
# W Face (to 6800m)                                   1
# W Face-N Ridge                                      1
# SE Face (recon)                                     1
# SE Ridge (to 5800m)                                 1
# YK/Main/Central-N Ridge up; W Face-SW Rib down      1
# SW Face up; S Ridge-SW side down                    1
# Y Kang/Main Smts-N Ridge up; S Ridge-S Smt down     1
# Left of GUlly of S Face of S Smt I (to 6600m)       1
# E Ridge (to 6000m)                                  1
# NW Ridge (to 5700m)                                 1
# S Col-SE Ridge up, NE Ridge-N Col down              1
# S Pillar-S Col (to 7900m)                           1
# N Face-N Ridge (to 7315m)                           1
# N Col-NE Ridge from Lho La (to 7600m) (illegal)     1
# SW Face (to 8380m)                                  1
# (From D-III-II) NE Ridge up; SE Ridge down          1
# (From D-V-III) S side up; S side of E Ridge down    1
# NW Face (3rd new rte) (to 6000m)                    1
# N Face                                              1
# South/Main/Cntrl Smts-N Ridge up; SE Ridge down     1
# Name: count, dtype: int64
# count                      30
# unique                     30
# top       NW Ridge (to 7200m)
# freq                        1
# Name: rte_3_name, dtype: object

# %% [markdown]
# `rte_4_name`: The fourth route name

# %%
rte_4_name = expeditions_data['rte_4_name']
print(rte_4_name.value_counts())            # How many of each unique rte_4_name occurs?
rte_4_name.describe()                       # Prints the total number of rows, how many unique rte_4_names there are, 
                                            # which variable occurs the most (and how many times)
# Out:
# rte_4_name
# NW Ridge (to 7200m)                                 1
# W Ridge-W Face from S                               1
# W Face (to 7000m)                                   1
# E Face (to 5200m)                                   1
# SW Ridge                                            1
# E Ridge up; SE Face down                            1
# NE Face (to 7500m)                                  1
# Makalu La-NW Ridge                                  1
# W Face (to 6550m)                                   1
# NW side (to 7100m)                                  1
# W Face (to 6800m)                                   1
# W Face-N Ridge                                      1
# SE Face (recon)                                     1
# SE Ridge (to 5800m)                                 1
# YK/Main/Central-N Ridge up; W Face-SW Rib down      1
# SW Face up; S Ridge-SW side down                    1
# Y Kang/Main Smts-N Ridge up; S Ridge-S Smt down     1
# Left of GUlly of S Face of S Smt I (to 6600m)       1
# E Ridge (to 6000m)                                  1
# NW Ridge (to 5700m)                                 1
# S Col-SE Ridge up, NE Ridge-N Col down              1
# S Pillar-S Col (to 7900m)                           1
# N Face-N Ridge (to 7315m)                           1
# N Col-NE Ridge from Lho La (to 7600m) (illegal)     1
# SW Face (to 8380m)                                  1
# (From D-III-II) NE Ridge up; SE Ridge down          1
# (From D-V-III) S side up; S side of E Ridge down    1
# NW Face (3rd new rte) (to 6000m)                    1
# N Face                                              1
# South/Main/Cntrl Smts-N Ridge up; SE Ridge down     1
# Name: count, dtype: int64
# count                      30
# unique                     30
# top       NW Ridge (to 7200m)
# freq                        1
# Name: rte_4_name, dtype: object

# %% [markdown]
# `team_asc_1`: The times that a team ascended for a certain route name (similar for the rest features with the same prefix)

# %%
team_asc_1 = expeditions_data['team_asc_1']
print(team_asc_1.value_counts())            # How many of each unique team_asc_1 occurs?
team_asc_1.describe()                       # Prints the total number of rows, how many unique team_asc_1s there are, 
                                            # which variable occurs the most (and how many times)
# Out:
# team_asc_1
# 1st                222
# 2nd                107
# 3rd                 69
# 4th                 55
# 1st,2nd             37
#                   ...
# 185,187,194          1
# 187,188,190,192      1
# 189,191              1
# 184                  1
# 8th,9th,11th         1
# Name: count, Length: 996, dtype: int64
# count     2709
# unique     996
# top        1st
# freq       222
# Name: team_asc_1, dtype: object

# %% [markdown]
# `is_disputed`: Success Disputed or Unverified

# %%
is_disputed = expeditions_data['is_disputed']
print(is_disputed.value_counts())           # How many of each unique is_disputed occurs?
is_disputed.describe()                      # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_disputed
# 0    10430
# 1       64
# Name: count, dtype: int64
# count    10494.000000
# mean         0.006099
# std          0.077860
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_disputed, dtype: float64

# %% [markdown]
# `is_claim`: Expedition claims that summited, however, without any evidence (probably a lie)

# %%
is_claim = expeditions_data['is_claim']
print(is_claim.value_counts())              # How many of each unique is_claim occurs?
is_disputed.describe()                      # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_claim
# 0    10464
# 1       30
# Name: count, dtype: int64
# count    10494.000000
# mean         0.006099
# std          0.077860
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_disputed, dtype: float64

# %% [markdown]
# `is_commercial_rte`: If the expedition was commercial

# %%
is_commercial_rte = expeditions_data['is_commercial_rte']
print(is_commercial_rte.value_counts())     # How many of each unique is_commercial_rte occurs?
is_commercial_rte.describe()                # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_commercial_rte
# 0    5312
# 1    5182
# Name: count, dtype: int64
# count    10494.000000
# mean         0.493806
# std          0.499985
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: is_commercial_rte, dtype: float64

# %% [markdown]
# `is_standard_rte`: If the route is standard (`S Col-SE Ridge` / `N Col-NE Ridge` / `N Col`)

# %%
is_standard_rte = expeditions_data['is_standard_rte']
print(is_standard_rte.value_counts())       # How many of each unique is_standard_rte occurs?
is_standard_rte.describe()                  # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_standard_rte
# 0    5398
# 1    5096
# Name: count, dtype: int64
# count    10494.000000
# mean         0.485611
# std          0.499817
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: is_standard_rte, dtype: float64

# %% [markdown]
# `other_smts`: Other peaks summited

# %%
other_smt = expeditions_data['other_smts']
print(other_smt.value_counts())             # How many of each unique other_smt occurs?
is_disputed.describe()                      # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# other_smts
# Climbed Island Peak                                                                                       57
# Climbed Lobuje East                                                                                       23
# Climbed Mera Peak                                                                                         20
# Island Peak                                                                                               18
# Summited Island Peak                                                                                      14
#                                                                                                           ..
# Climbed Kangchenjunga (KANG-091-07) and Makalu (MAKA-091-09)                                               1
# Climbed Kangchenjunga (KANG-091-08)                                                                        1
# Climbed Manaslu (MANA-091-05)                                                                              1
# Attempted Tukuche (TUKU-083-04)                                                                            1
# Attempted Makalu (MAKA-893-02) and Kangchungste (Makalu II) (MAK2-893-01); climbed Chago (CHAG-893-01)     1
# Name: count, Length: 1807, dtype: int64
# count    10494.000000
# mean         0.006099
# std          0.077860
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_disputed, dtype: float64

# %% [markdown]
# `approach`: Main expedition intermediate points to reach the mountain

# %%
approach = expeditions_data['approach']
print(approach.value_counts())              # How many of each unique approach occurs?
approach.describe()                         # Prints the total number of rows, number of unique approaches there are,
                                            # which variable occurs the most (and how many times)
# Out:
# approach
# Zhangmu Nyalam Tingri                                     200
# KTM Tingri BC                                             132
# Pangboche                                                 125
# Lukla Namche Pangboche Everest BC                         114
# Kodari Tingri BC                                          110
#                                                          ...
# Darbang Italian BC BC                                       1
# Beni Darban by bus Khamla Boghara Dobang Italian BC         1
# Beni Darban Italian BC                                      1
# Jomson by air, trek to Marpha Dhampus Pass French Pass      1
# Tumlingtar Num Sedua Dobate Yangle Kharka Langmale          1
# Name: count, Length: 2410, dtype: int64
# count                      5081
# unique                     2410
# top       Zhangmu Nyalam Tingri
# freq                        200
# Name: approach, dtype: object

# %% [markdown]
# `bc_arrived`: Arrival data at the base camp

# %%
bc_arrived = expeditions_data['bc_arrived']
print(bc_arrived.value_counts())            # How many of each unique bc_arrived occurs?
bc_arrived.describe()                       # Prints the total number of rows, number of unique bc_arriveds there are,
                                            # which variable occurs the most (and how many times)
# Out:
# bc_arrived
# 2011-04-14    23
# 2009-04-19    20
# 2005-04-14    20
# 2018-04-16    18
# 2006-04-10    18
#               ..
# 1959-04-03     1
# 1969-04-21     1
# 1970-09-06     1
# 1976-03-18     1
# 1989-11-27     1
# Name: count, Length: 4231, dtype: int64
# count           9345
# unique          4231
# top       2011-04-14
# freq              23
# Name: bc_arrived, dtype: object

# %% [markdown]
# `bc_left`: Departure date from the base camp

# %%
bc_left = expeditions_data['bc_left']
print(bc_left.value_counts())           # How many of each unique bc_left occurs?
bc_left.describe()                      # Prints the total number of rows, number of unique bc_lefts there are,
                                        # which variable occurs the most (and how many times)
# Out:
# bc_left
# 2006-05-21    26
# 2009-05-23    24
# 2019-05-25    23
# 2011-05-24    23
# 2013-05-24    23
#               ..
# 1983-10-12     1
# 1983-05-26     1
# 1983-05-24     1
# 1983-01-01     1
# 2017-04-29     1
# Name: count, Length: 3306, dtype: int64
# count           8055
# unique          3306
# top       2006-05-21
# freq              26
# Name: bc_left, dtype: object

# %% [markdown]
# `total_days`: Total number of days spent by the expedition

# %%
total_day = expeditions_data['total_days']
print(total_day.value_counts())             # How many of each unique total_day occurs?
total_day.describe()                        # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# total_days = []                                # List of Unique years
# for i in year:
#     if i in total_days:
#         continue
#     elif i not in total_days:
#         total_days.append(i)
# print(len(total_days))
# Out:
# total_days
# 0     2461
# 14     256
# 12     237
# 15     220
# 11     219
#       ...
# 68       1
# 85       1
# 90       1
# 96       1
# 97       1
# Name: count, Length: 97, dtype: int64
# count    10494.000000
# mean        20.280541
# std         17.655621
# min          0.000000
# 25%          4.000000
# 50%         18.000000
# 75%         32.000000
# max        280.000000
# Name: total_days, dtype: float64

# %% [markdown]
# `exp_result`: The result of the expedition

# %%
exp_result = expeditions_data['exp_result']
print(exp_result.value_counts())            # How many of each unique exp_result occurs?
exp_result.describe()                       # Prints the total number of rows, number of unique exp_results there are,
                                            # which variable occurs the most (and how many times)
# Out:
# exp_result
# Success                       5692
# Bad Weather                   1308
# Bad Conditions                1109
# Illness, AMS                   465
# Route Difficulty               439
# Other                          316
# Accident                       296
# Did not Climb                  233
# Last of Supplies               220
# Success (Subpeak, ForeSmt)     121
# Unknown                        106
# Lack of Time                    92
# Not to Reach BC                 64
# Success (Claimed)               21
# Attempt Rumored                 12
# Name: count, dtype: int64
# count       10494
# unique         15
# top       Success
# freq         5692
# Name: exp_result, dtype: object

# %%
### I started manually adding them into success and not success ###

No_Success = {
    'Bad Weather': 'No_Success',
    'Bad Conditions': 'No_Success',
    'Illness, AMS': 'No_Success',
    'Route Difficulty': 'No_Success',
    'Accident': 'No_Success',
    'Did not Climb': 'No_Success',
    "Last of Supplies": 'No_Success',
    "Lack of Time": 'No_Success',
    "Not to Reach BC": 'No_Success',
}

Success = {
    'Success': 'Success',
    'Success (Subpeak, ForeSmt)': 'Success',
    'Success (Claimed)': 'Success',
}
exp_result1 = exp_result.replace(Success).replace(No_Success)

print(exp_result1.value_counts())            # How many of each unique exp_result1 occurs?
exp_result1.describe()                       # Prints the total number of rows, number of unique exp_result1s there are,
                                             # which variable occurs the most (and how many times)
# Out:
# exp_result
# Success            5834
# No_Success         4226
# Other               316
# Unknown             106
# Attempt Rumored      12
# Name: count, dtype: int64
# count       10494
# unique          5
# top       Success
# freq         5834
# Name: exp_result, dtype: object

# %% [markdown]
# `is_traverse`: If the traverse has been made (?)

# %%
is_traverse = expeditions_data['is_traverse']
print(is_traverse.value_counts())           # How many of each unique is_traverse occurs?
is_traverse.describe()                      # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_traverse
# 0    10392
# 1      102
# Name: count, dtype: int64
# count    10494.000000
# mean         0.009720
# std          0.098114
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_traverse, dtype: float64

# %% [markdown]
# `is_ski_snowboard`: If the descent has been made using ski/snowboard

# %%
is_ski_snowboard = expeditions_data['is_ski_snowboard']
print(is_ski_snowboard.value_counts())      # How many of each unique is_ski_snowboard occurs?
is_ski_snowboard.describe()                 # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_ski_snowboard
# 0    10324
# 1      170
# Name: count, dtype: int64
# count    10494.000000
# mean         0.016200
# std          0.126249
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_ski_snowboard, dtype: float64

# %% [markdown]
# `is_parapente`: If the descent has been made using parapente

# %%
is_parapente = expeditions_data['is_parapente']
print(is_parapente.value_counts())          # How many of each unique is_parapente occurs?
is_parapente.describe()                     # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_parapente
# 0    10466
# 1       28
# Name: count, dtype: int64
# count    10494.000000
# mean         0.002668
# std          0.051588
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_parapente, dtype: float64

# %% [markdown]
# `term_note`: Summit termination details/results

# %%
term_note = expeditions_data['term_note']
print(term_note.value_counts())             # How many of each unique term_note occurs?
term_note.describe()                        # Prints the total number of rows, number of unique term_notes there are,
                                            # which variable occurs the most (and how many times)
# Out:
# term_note
# Abandoned at 5350m due to Sherpa strike                                  37
# Abandoned due to earthquake                                              33
# Termination reason unknown                                               20
# Abandoned at 7100m due to bad weather                                    18
# Stopped at fore-summit (8125m) due to end of fixed-rope                  15
#                                                                          ..
# Abandoned at 7700m due to bad weather, high winds and snowfall            1
# Abandoned at 7100m due to fatal avalanche                                 1
# Abandoned at 7500m due to high winds and difficult overhanging pillar     1
# Abandoned at 7600m due to bad weather and death of member                 1
# Abandoned at 6330m due to bad weather                                     1
# Name: count, Length: 3767, dtype: int64
# count                                        4416
# unique                                       3767
# top       Abandoned at 5350m due to Sherpa strike
# freq                                           37
# Name: term_note, dtype: object

# %% [markdown]
# `summit_day`: Day of the summit  (YYYY-MM-DD)

# %%
summit_day = expeditions_data['summit_day']
print(summit_day.value_counts())            # How many of each unique summit_day occurs?
summit_day.describe()                       # Prints the total number of rows, number of unique summit_days there are,
                                            # which variable occurs the most (and how many times)
# Out:
# summit_day
# 2012-05-19    53
# 2019-05-23    38
# 2016-05-19    37
# 2011-05-20    36
# 2009-05-19    33
#               ..
# 1980-05-18     1
# 1981-05-22     1
# 1981-05-17     1
# 1981-06-02     1
# 1989-12-20     1
# Name: count, Length: 3973, dtype: int64
# count           9832
# unique          3973
# top       2012-05-19
# freq              53
# Name: summit_day, dtype: object

# %% [markdown]
# `time`: Summit time  (XX:XX)

# %%
time = expeditions_data['time']
print(time.value_counts())      # How many of each unique time occurs?
time.describe()                 # Prints the total number of rows, number of unique term_notes there are,
                                # which variable occurs the most (and how many times)
# Out:
# time
# 11:00    236
# 10:00    208
# 12:00    184
# 13:00    152
# 10:30    148
#         ...
# 11:24      1
# 06:29      1
# 08:09      1
# 09:21      1
# 15:08      1
# Name: count, Length: 419, dtype: int64
# count      4593
# unique      419
# top       11:00
# freq        236
# Name: time, dtype: object

# %% [markdown]
# `max_elev_reached`: Max elevation reached by the expedition

# %%
max_elev_reached = expeditions_data['max_elev_reached']
print(max_elev_reached.value_counts())      # How many of each unique max_elev_reached occurs?
max_elev_reached.describe()                 # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# MAX_ELEV_REACHED = []                                  # List of Unique max_elev_reacheds
# for i in max_elev_reached:
#     if i in MAX_ELEV_REACHED:
#         continue
#     elif i not in MAX_ELEV_REACHED:
#         MAX_ELEV_REACHED.append(i)
# print(len(MAX_ELEV_REACHED))
# Out:
# max_elev_reached
# 8850    1323
# 6814     987
# 8188     842
# 0        425
# 8163     352
#         ...
# 6035       1
# 7685       1
# 6093       1
# 6356       1
# 6206       1
# Name: count, Length: 696, dtype: int64
# count    10494.000000
# mean      7106.911187
# std       1763.608343
# min          0.000000
# 25%       6530.000000
# 50%       7200.000000
# 75%       8188.000000
# max       8850.000000
# Name: max_elev_reached, dtype: float64

# %% [markdown]
# `summit_days`: Day of the summit according to total_days feature

# %%
SUMMIT_DAY = expeditions_data['summit_days']
print(SUMMIT_DAY.value_counts())        # How many of each unique SUMMIT_DAY occurs?
SUMMIT_DAY.describe()                   # Prints the total number of rows, mean, standard deviation,
                                        # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# summit_days
# 0      1356
# 10      311
# 12      307
# 9       294
# 13      287
#        ...
# 97        1
# 77        1
# 68        1
# 122       1
# 388       1
# Name: count, Length: 87, dtype: int64
# count    10494.000000
# mean        19.065752
# std         15.719713
# min          0.000000
# 25%          7.000000
# 50%         17.000000
# 75%         29.000000
# max        388.000000
# Name: summit_days, dtype: float64

# %% [markdown]
# `total_mbrs`: Total number of expedition members that have summited

# %%
total_mbr = expeditions_data['total_mbrs']
print(total_mbr.value_counts())         # How many of each unique total_mbr occurs?
total_mbr.describe()                    # Prints the total number of rows, mean, standard deviation,
                                        # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# total_mbrs
# 2     1564
# 1     1522
# 3     1054
# 4     1026
# 5      846
# 6      829
# 7      671
# 8      585
# 9      436
# 10     381
# 11     292
# 12     250
# 13     188
# 14     142
# 15     131
# 16      98
# 17      69
# 18      56
# 20      55
# 0       50
# 19      48
# 21      28
# 22      23
# 23      20
# 25      17
# 27      16
# 24      16
# 28      12
# 34       8
# 29       6
# 30       6
# 31       6
# 35       5
# 26       5
# 36       5
# 42       3
# 32       3
# 37       2
# 39       2
# 50       2
# 49       2
# 52       2
# 33       2
# 48       1
# 44       1
# 72       1
# 47       1
# 41       1
# 76       1
# 40       1
# 99       1
# 65       1
# 62       1
# Name: count, dtype: int64
# count    10494.000000
# mean         5.942920
# std          5.410798
# min          0.000000
# 25%          2.000000
# 50%          5.000000
# 75%          8.000000
# max         99.000000
# Name: total_mbrs, dtype: float64

# %% [markdown]
# `mbrs_summited`: Total number of expedition members that have summited

# %%
mbrs_summited = expeditions_data['mbrs_summited']
print(mbrs_summited.value_counts())         # How many of each unique mbrs_summited occurs?
mbrs_summited.describe()                    # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# mbrs_summited
# 0     4842
# 1     1553
# 2     1374
# 3      758
# 4      608
# 5      396
# 6      264
# 7      176
# 8      141
# 9      106
# 10      69
# 11      49
# 12      38
# 14      27
# 13      24
# 15      17
# 16      13
# 17       7
# 23       5
# 20       5
# 18       4
# 27       2
# 24       2
# 21       2
# 29       2
# 22       2
# 28       2
# 19       2
# 32       1
# 39       1
# 30       1
# 25       1
# Name: count, dtype: int64
# count    10494.000000
# mean         1.867257
# std          2.894572
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# max         39.000000
# Name: mbrs_summited, dtype: float64

# %% [markdown]
# `mbrs_deaths`: Total number of expedition members that died

# %%
mbrs_death = expeditions_data['mbrs_deaths']
print(mbrs_death.value_counts())        # How many of each unique mbrs_death occurs?
mbrs_death.describe()                   # Prints the total number of rows, mean, standard deviation,
                                        # minimum, maximum, lower quartile, upper quartile, and median
# mbrs_deaths = []                                  # List of Unique mbrs_deaths
# for i in mbrs_death:
#     if i in mbrs_deaths:
#         continue
#     elif i not in mbrs_deaths:
#         mbrs_deaths.append(i)
# print(len(mbrs_deaths))
# Out:
# mbrs_deaths
# 0     9931
# 1      422
# 2       96
# 3       26
# 4        9
# 5        8
# 7        1
# 10       1
# Name: count, dtype: int64
# count    10494.000000
# mean         0.074805
# std          0.374835
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         10.000000
# Name: mbrs_deaths, dtype: float64

# %%
# displays number of deaths per expedition (even when zero) (below)
members_deaths = expeditions_data['mbrs_deaths']
#print(members_deaths)

# when mbrs_deaths != 0 --> death(s) occured during the expedition
non_zero_deaths = expeditions_data[members_deaths != 0]
print('Number of expeditions where deaths occur:' , len(non_zero_deaths))
# Out:
# Number of expeditions where deaths occur: 563

# %% [markdown]
# `high_camps`: Number of high camps

# %%
high_camp = expeditions_data['high_camps']
print(high_camp.value_counts())         # How many of each unique high_camp occurs?
high_camp.describe()                    # Prints the total number of rows, mean, standard deviation,
                                        # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# high_camps
# 3     2717
# 2     2266
# 0     2187
# 4     1859
# 1     1065
# 5      248
# 6      115
# 7       22
# 8        6
# 9        3
# 12       1
# 34       1
# 14       1
# 17       1
# 10       1
# 11       1
# Name: count, dtype: int64
# count    10494.000000
# mean         2.233753
# std          1.574589
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         34.000000
# Name: high_camps, dtype: float64

# %% [markdown]
# `hired_abc`: ?

# %%
hired_abc = expeditions_data['hired_abc']
print(hired_abc.value_counts())         # How many of each unique hired_abc occurs?
hired_abc.describe()                    # Prints the total number of rows, mean, standard deviation,
                                        # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# hired_abc
# 0     3706
# 1     1668
# 2     1537
# 3     1067
# 4      697
# 5      428
# 6      297
# 7      188
# 8      170
# 9      124
# 10     120
# 12      67
# 11      65
# 15      49
# 14      43
# 13      37
# 16      25
# 20      25
# 23      17
# 22      16
# 17      16
# 25      13
# 18      12
# 19      11
# 26       9
# 24       8
# 21       7
# 30       7
# 28       7
# 40       4
# 27       4
# 29       4
# 60       4
# 35       4
# 33       4
# 42       3
# 32       3
# 50       3
# 99       3
# 55       2
# 46       2
# 44       2
# 36       2
# 31       2
# 65       2
# 43       2
# 88       1
# 56       1
# 48       1
# 59       1
# 37       1
# 34       1
# 54       1
# 41       1
# Name: count, dtype: int64
# count    10494.000000
# mean         2.787116
# std          5.066210
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# max         99.000000
# Name: hired_abc, dtype: float64

# %% [markdown]
# `hired_summits`: ?

# %%
hired_summit = expeditions_data['hired_summits']
print(hired_summit.value_counts())          # How many of each unique hired_summit occurs?
hired_summit.describe()                     # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# hired_summits
# 0     7082
# 1     1157
# 2      921
# 3      459
# 4      280
# 5      169
# 6      102
# 7       71
# 8       62
# 9       41
# 10      30
# 13      22
# 11      17
# 12      16
# 14      11
# 21       9
# 15       7
# 16       7
# 17       6
# 20       4
# 22       3
# 24       3
# 25       2
# 26       2
# 32       2
# 33       1
# 35       1
# 19       1
# 28       1
# 48       1
# 23       1
# 27       1
# 43       1
# 18       1
# Name: count, dtype: int64
# count    10494.000000
# mean         1.010101
# std          2.437417
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         48.000000
# Name: hired_summits, dtype: float64

# %% [markdown]
# `hired_deaths`: ?

# %%
hired_death = expeditions_data['hired_deaths']
print(hired_death.value_counts())       # How many of each unique hired_death occurs?
hired_death.describe()                  # Prints the total number of rows, mean, standard deviation,
                                        # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# hired_deaths
# 0     10282
# 1       164
# 2        26
# 3        10
# 4         4
# 6         3
# 5         2
# 7         1
# 11        1
# 10        1
# Name: count, dtype: int64
# count    10494.000000
# mean         0.030303
# std          0.282998
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         11.000000
# Name: hired_deaths, dtype: float64

# %% [markdown]
# `rope_fixed`: total rope length that has been fixed on the mountain/route

# %%
rope_fixed = expeditions_data['rope_fixed']
print(rope_fixed.value_counts())        # How many of each unique rope_fixed occurs?
rope_fixed.describe()                   # Prints the total number of rows, mean, standard deviation,
                                        # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# rope_fixed
# 0       8678
# 200      200
# 400      142
# 600      108
# 1000     100
#         ...
# 1010       1
# 6400       1
# 6600       1
# 1050       1
# 4240       1
# Name: count, Length: 144, dtype: int64
# count    10494.000000
# mean       184.621022
# std        691.978138
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max       8700.000000
# Name: rope_fixed, dtype: float64

# %% [markdown]
# `is_no_hired_abc`: ?

# %%
is_no_hired_abc = expeditions_data['is_no_hired_abc']
print(is_no_hired_abc.value_counts())       # How many of each unique is_no_hired_abc occurs?
is_no_hired_abc.describe()                  # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_no_hired_abc
# 0    7013
# 1    3481
# Name: count, dtype: int64
# count    10494.000000
# mean         0.331713
# std          0.470851
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: is_no_hired_abc, dtype: float64

# %% [markdown]
# `is_o2_not_used`: If O2 has not been used

# %%
is_o2_not_used = expeditions_data['is_o2_not_used']
print(is_o2_not_used.value_counts())        # How many of each unique is_o2_not_used occurs?
is_o2_not_used.describe()                   # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_o2_not_used
# 1    7413
# 0    3081
# Name: count, dtype: int64
# count    10494.000000
# mean         0.706404
# std          0.455431
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: is_o2_not_used, dtype: float64

# %% [markdown]
# `is_o2_climbing`: If O2 has been used during climbing

# %%
is_o2_climbing = expeditions_data['is_o2_climbing']
print(is_o2_climbing.value_counts())        # How many of each unique is_o2_climbing occurs?
is_o2_climbing.describe()                   # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_o2_climbing
# 0    7879
# 1    2615
# Name: count, dtype: int64
# count    10494.000000
# mean         0.249190
# std          0.432565
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_o2_climbing, dtype: float64

# %% [markdown]
# `is_o2_descent`: If O2 has been used only on descent

# %%
is_o2_descent = expeditions_data['is_o2_descent']
print(is_o2_descent.value_counts())         # How many of each unique is_o2_descent occurs?
is_o2_descent.describe()                    # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_o2_descent
# 0    10348
# 1      146
# Name: count, dtype: int64
# count    10494.000000
# mean         0.013913
# std          0.117134
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_o2_descent, dtype: float64

# %% [markdown]
# `is_o2_medical`: If O2 has been used for medical reasons

# %%
is_o2_medical = expeditions_data['is_o2_medical']
print(is_o2_medical.value_counts())         # How many of each unique is_o2_medical occurs?
is_o2_medical.describe()                    # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_o2_medical
# 0    10172
# 1      322
# Name: count, dtype: int64
# count    10494.000000
# mean         0.030684
# std          0.172469
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_o2_medical, dtype: float64

# %% [markdown]
# `is_o2_unkwn`: It's unknown whether O2 has been used or not

# %%
is_o2_unkwn = expeditions_data['is_o2_unkwn']
print(is_o2_unkwn.value_counts())           # How many of each unique is_o2_unkwn occurs?
is_o2_unkwn.describe()                      # Prints the total number of rows, mean, standard deviation,
                                            # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# is_o2_unkwn
# 0    10470
# 1       24
# Name: count, dtype: int64
# count    10494.000000
# mean         0.002287
# std          0.047770
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_o2_unkwn, dtype: float64

# %% [markdown]
# `had_o2`: O2 has been taken but unused

# %%
had_o2 = expeditions_data['had_o2']
print(had_o2.value_counts())            # How many of each unique had_o2 occurs?
had_o2.describe()                       # Prints the total number of rows, mean, standard deviation,
                                        # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# had_o2
# 0    9585
# 1     909
# Name: count, dtype: int64
# count    10494.000000
# mean         0.086621
# std          0.281292
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: had_o2, dtype: float64

# %% [markdown]
# `camp_sites`: Expedition camps locations

# %%
camp_site = expeditions_data['camp_sites']
print(camp_site.value_counts())         # How many of each unique camp_site occurs?
camp_site.describe()                    # Prints the total number of rows, mean, standard deviation,
                                        # minimum, maximum, lower quartile, upper quartile, and median
# Out:
# camp_sites
# No Smt                                                                                            30
# BC(5350m),xxx                                                                                     27
# BC(5350m)                                                                                         23
# Smt(01/11)                                                                                         9
# xxx(6400m)                                                                                         7
#                                                                                                   ..
# ABC(21/04,5700m),C1(23/04,6400m),C2(27/04,7100m),xxx(27/04,7100m)                                  1
# BC(17/04,5000m),ABC(26/04,5700m),C1(05/05,6400m),xxx(05/05,6400m)                                  1
# BC(17/04,4900m),ABC(21/04,5700m),C1(23/04,6400m),C2(05/05,7100m),C3(11/05,7450m),Smt(13,17/05)     1
# BC(03/05,5000m),ABC(06/05,5700m),C1(08/05,6400m),C2(10/04,7200m),xxx(12/05,7400m)                  1
# BC(25/04,5300m),ABC(27/04,5800m),xxx(28/04,6330m)                                                  1
# Name: count, Length: 9827, dtype: int64
# count      10154
# unique      9827
# top       No Smt
# freq          30
# Name: camp_sites, dtype: object

# %% [markdown]
# `accidents`: Accident description

# %%
accident = expeditions_data['accidents']
print(accident.value_counts())          # How many of each unique accident occurs?
accident.describe()                     # Prints the total number of rows, number of unique accidents there are,
                                        # which variable occurs the most (and how many times)
# Out:
# accidents
# Nothing serious                                                                     128
# Nothing                                                                             116
# No accidents or frostbite                                                             7
# No accidents                                                                          4
# Nothing very serious                                                                  3
#                                                                                    ...
# Fabrizio Defrancesco's cerebral edema; Fabrizio Bartoli ear problems                  1
# Frostbite both members noses, Kim's two right toes and fingers (but not serious)      1
# Sikk suffered stroke at 7000m (below C2)                                              1
# Cronin suffered from high altitude sickness (vomiting)                                1
# Fatal fall of Chhanda Gayen and 2 Sherpas                                             1
# Name: count, Length: 2691, dtype: int64
# count                2971
# unique               2691
# top       Nothing serious
# freq                  128
# Name: accidents, dtype: object

# %%
### I started manually adding them then realized how large the dataset is. ###
### Many entries that mean the same thing ###

no_incident = {
    'Nothing serious': 'no incident',
    'Nothing': 'no incident',
    'No accidents or frostbite': 'no incident',
    'No accidents': 'no incident',
    'Nothing very serious': 'no incident',
    #'None serious - slight altitude problems': 'incident',
    "None serious - slight altitude problems": 'no incident',
    "No accidents, frostbite or serious illness": 'no incident',
}
accident = accident.replace(no_incident)

incident = {
    'Fatal fall': 'incident',
    'Some avalanches on Oct 7-9, but no one hit (across route above BC and took out some fixed rope); Hamatani altitude sickness; Yuasa left BC with Hamatani after Hamatani had returned to expedition and again got sick': 'incident',
    'Fatal avalanche': 'incident',
    'Only slight frostbite': 'incident',
    '1 member died of illness': 'incident',
    'Climbing Ghustung Ridge, 1 member hit in leg by falling stone but climbed later; 2 members who did not make a summit had altitude sickness and stayed at C4 2 nights, descended Sept 15': 'incident',
    'Lhotse snowblindness': 'incident',
    'Gregory altitude sickness': 'incident',
    'Only fatal fall': 'incident',
    '1 member slighe injury to leg on Cholatse': 'incident',
    '1 member altitude sickness': 'incident',
    'Minor frostbite in finger tips (right hand) of Bogomolov': 'incident',
    '1 member slight injury to leg on Cholatse': 'incident',
    'Wilson hit by falling stone in 1st biv in tent': 'incident',
    'Altitude sickness': 'incident',
    "Miss Kim's Face wounded by strong wind; 2 Sherpas slightly hurt by avalanche": 'incident',
    "Zupan lightly grazed by falling stone; 4 members little frozen fingers": 'incident',
    "Ice and rock falls hit several members (broke 1 man's helmet) on terrible route between C2-C3 which had nearly constantly falling ice and rock; 1 man had frostbitten toes that will heal": 'incident',
    "Minor frostbite only": 'incident',
    "Sato fell into crevasse": 'incident',
    "None except fatal fall": 'incident',
    "All members have frostnipped toes": 'incident',
    "Fraser and Harris disappeared on way to summit (fall?)": 'incident',
    "Sakamoto and Suzuki killed by avalanche at C2": 'incident',
    "Lee Tae-Yul's shoulder injured when serac avalanche broke tents & struck him (put out of action); Kim Chul-Han arm injured by falling ice block (put out of action); Ang Tshering leg broken; Park Chung-Sang slightly hurt leg in 10m fall": 'incident',
    "13th April avalanche hit C3 and tent collasped (2 men cut tent with knife and got out)": 'incident',
    "Wirz fell 2m at 4500m Sep 24, injured shoulder ('stupid accident')": 'incident',
    "Simpson frostnipped toes of both feet": 'incident',

    "Woolums very ill and never reached BC, left expedition 3rd or 4th Oct; Teare developing altitude sickness at C2": 'incident',
    "Fatal fall by Hartman": 'incident',
    "Camps and climbers swept away by avalanche; helicopter search on Nov 20 saw no trace": 'incident',

    "Tsang broke his leg in a fall after summit": 'incident',
    "Breathing problem of Duran": 'incident',
    "Rivas altitude sickness": 'incident',
    "Slab avalanche bruised ribs of Roeoesli-Zingg": 'incident',
    "Ojala's illness": 'incident',

    "Feja got Giardia and left BC 9 Oct": 'incident',
    "Anu had frostbite (all fingers first digits)": 'incident',
    "1 Sherpa slightly injured": 'incident',
    "Frostbite on all 10 fingers and 10 toes by Andreas Eckhart; on 3 fingers on right hand by Schmuck": 'incident',
    "Isihara blood supply to brain got problem while flying to Kathmandu by helicopter on 22 Aug": 'incident',
    "G. P. Kumar and Sirdar Pasang Gombu had 2 frostbitten fingers": 'incident',
    "Jakobsen suffered from high altitude sickness": 'incident',
    "Kanchha Sherpa's fingers got frostbitten on 12 May on way down to C1 from C2 (he left ABC on 14 May for Kathmandu)": 'incident',
    "Frostbite left-hand fingers except thumb of Norieka": 'incident',
    "Leader had pneumonia": 'incident',
    "Nijs got frostbite on three middle toes of right foot": 'incident',
    "Ronald Naar died of altitude sickness": 'incident',
    "Rudolf Bosiak and Dusan Myslivec chest infections": 'incident',
    "Krpec died on 23 or 24 September": 'incident',
    "Chris frostbite on toe": 'incident',
    "Sherpa frostbitten fingers": 'incident',
    "Neefjes frostbitten fingers; Verhoere fatal fall": 'incident',
    "3 cases of altitude sickness": 'incident',
    "Rodriguez's altitude problem; Quintero's fall": 'incident',
    "Bergant fell at 9:00 pm on Apr 22 because very tired without oxygen (at 8300m just below connecting ridge); no serious frostbite or illnesses": 'incident',
    "Vrabie suffered from pneumonia; Crina from headache": 'incident',
    "Collingson altitude sickness": 'incident',
    "Denderuk suffered from severe cough": 'incident',
    "Amirov suffered from cough and sore throat": 'incident',
    "Farkas frostbitten feet and toes": 'incident',
    'Christian Sterr stomach trouble': 'incident',
    'Nakamura slight frostbite': 'incident',
    "Saluvere's pulmonary edema": 'incident',
    "Vinot's temporary chest infection": 'incident',
    "Leader hit by falling stone which left him unconscious 10 minutes": 'incident',
    'Marcos frostbite': 'incident',
    'Audy felt dizziness at 7400m on his way up': 'incident',
    'Sanchez got AMS (vomiting at around 6600m while trying to get to C2)': 'incident',
    '7 rope team members injured in avalanche at about 7800m on 17 Sept': 'incident',
    '3 fatalities on summit ascent; Kim Sang-Ho severe altitude sickness and stayed below BC': 'incident',
    "Langeland eyes problem in C2; Valseth got chest infection in CBC": 'incident',
    "Onu suffered from altitude sickness and never went above ABC": 'incident',
    "Fatal fall by Nones; Nocker's edema": 'incident',
    "Two members edema": 'incident',
    "Cook nearly died of pulmonary edema on approach march near BC; falling stones, but no injuries": 'incident',
    "Fabrizio Defrancesco's cerebral edema; Fabrizio Bartoli ear problems": 'incident',
    "Frostbite both members noses, Kim's two right toes and fingers (but not serious)": 'incident',
    'Sikk suffered stroke at 7000m (below C2)': 'incident',
    'Cronin suffered from high altitude sickness (vomiting)': 'incident',
    'Fatal fall of Chhanda Gayen and 2 Sherpas': 'incident',
}
accident = accident.replace(incident)

# incident or no_incident?
# 'None serious - slight altitude problems': 'incident',

# %%
# for i in accident:
#     if i in accidents:
#         continue
#     elif i not in accidents:
#         accidents.append(i)
# print(accident.value_counts())                 # How many of each unique accident occurs?
# print(len(accident))

# %% [markdown]
# `achievements`: Achievement description

# %%
achievement = expeditions_data['achievements']
print(achievement.value_counts())       # How many of each unique achievement occurs?
achievement.describe()                  # Prints the total number of rows, number of unique achievements there are,
                                        # which variable occurs the most (and how many times)
# Out:
# achievements
# 1st ascent                               20
# 1st Korean ascent                         7
# 1st solo ascent                           6
# 1st attempt on mountain                   5
# 1st Korean attempt                        4
#                                          ..
# 1st woman atop Everest without oxygen     1
# 1st Korean death on Everest               1
# 1st married couple to summit              1
# 1st attempt of E Ridge                    1
# 1st ascent of Yanme Kang                  1
# Name: count, Length: 845, dtype: int64
# count            934
# unique           845
# top       1st ascent
# freq              20
# Name: achievements, dtype: object

# %% [markdown]
# `agency`: Commercial agency name

# %%
agency = expeditions_data['agency']
print(agency.value_counts())        # How many of each unique agency occurs?
agency.describe()                   # Prints the total number of rows, number of unique agencies there are,
                                    # which variable occurs the most (and how many times)
# Out:
# agency
# Asian Trekking                  853
# Thamserku Trekking              705
# Himalayan Guides                384
# Seven Summit Treks              333
# Cosmo Treks                     293
#                                ...
# Tibetan Mountaineering Assoc      1
# High Ambition                     1
# Pun Hill                          1
# Saathi Nepal                      1
# Nepal Army                        1
# Name: count, Length: 876, dtype: int64
# count               8805
# unique               876
# top       Asian Trekking
# freq                 853
# Name: agency, dtype: object

# %% [markdown]
# `members`: Expedition members (name: `L - Leader`, `S - Summited`, `D - Died`)

# %%
member = expeditions_data['members']
print(member.value_counts())        # How many of each unique member occurs?
member.describe()                   # Prints the total number of rows, number of unique members there are,
                                    # which variable occurs the most (and how many times)
# Out:
# members
# 01  Wilfried Josef Studer (L), Austria 02  Ms. Sylvia Brigitte Studer, Austria                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             8
# 01  Paulo Rogerio Pinto Coelho (L), Brazil 02  Ms. Helena Guiro Pacheco Pinto Coelho, Brazil                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               6
# 01  Luigi Aldo Rampini (L), Italy                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          6
# 01  Richard Leopoldo Hidalgo Jara (L), Peru                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                6
# 01  Mischa Saleki (L), W Germany/Iran                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      5
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ..
# 01  Michael Aaron Hamill (L), USA 02  Maximillien Peter (Max) Bunce, USA 03  Graham M. Austin, Australia 04  Juerg Bandle, Switzerland 05  Charles Bickes, USA 06  Markus Paul Buel, Switzerland 07  Ms. Yonsuk Suzanna Derby, USA 08  Noah Devereux, UK 09  Carl Dean Duester, USA 10  Karl Wolfgang Flock, Germany 11  Andrew Maleckyj, Canada 12  Ms. Vanessa Audi Rhys O'Brien, USA 13  Wolfgang Thomaseth, Italy 14  Ms. Valari Boker Wedell, USA 15  Dawa Nuru (Danuru) Sherpa, Phortse, Khumbu 16  Karma Rita Sherpa, Phortse, Khumbu 17  Mingma Tenzing Sherpa, Phortse, Khumbu    1
# 01  Jae-Soo Kim (L), S Korea 02  Byung-Woo Son, S Korea 03  Pasang Lama Bhote, Hungung, Hatiya-1, Makalu-Barun 04  Lhakpa Wangdi Sherpa, Chheskam, Solukhumbu 05  Pema Tshering Sherpa, Walung, Makalu-9, Makalu-Barun                                                                                                                                                                                                                                                                                                                                                                     1
# 01  Maximo Gustavo Kausch Serantes (L), UK/Argentina 02  Dean Daniel Cardinale, USA 03  Mark Herbick, USA 04  Calin Lewis, USA 05  Ms. Julie Miles Lewis, UK 06  Stephen Ranger, UK 07  Paul Charles Rizza, UK 08  Matti Antero Sunell, Finland 09  Michael Anthony Tomordy, UK 10  Rolf Vetter, Switzerland 11  Ms. Nathalie Virag, Switzerland 12  Lhakpa Gelu (Lhakpa Gelbu) Sherpa, Thumduk, Beni, Solukhumbu 13  Rajen (Raj) Thapa Magar, Nepal                                                                                                                                       1
# 01  Leopold Paul Goven (L), Belgium                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# 01  Pascal Manetsch (L), Switzerland 02  Severin Bucher, Switzerland 03  Ms. Flutura (Uta) Ibrahimi, Kosovo 04  Dominik Adolf Siegfried Nitsch, Germany 05  Marc Andri Riedi, Switzerland 06  Ms. Natalie Susan Voegeli, Switzerland 07  Dorje/Dorchi Sherpa, Dobhane-9, Bhojpur 08  Nima Tashi Sherpa, Gudel-4, Solukhumbu 09  Pasang Tendi Sherpa, Kharikhola, Solukhumbu                                                                                                                                                                                                                1
# Name: count, Length: 10197, dtype: int64
# count                                                 10480
# unique                                                10197
# top       01  Wilfried Josef Studer (L), Austria 02  Ms....
# freq                                                      8
# Name: members, dtype: object

# %%
# Group by season and sum the number of members who summited
season_summits = expeditions_data.groupby('season')['mbrs_summited'].sum()

# Sort values (highest summit rate on the left)
season_summits = season_summits.sort_values(ascending=False)

plt.figure(figsize=(6,4))
plt.bar(season_summits.index, season_summits.values)

plt.title('Members Summited vs Season')
plt.xlabel('Season')
plt.ylabel('Members Summited')
plt.show()

# %%
# Group by year and sum the number of members who died
year_deaths = expeditions_data.groupby('year')['mbrs_deaths'].sum()

# Sort values (highest summit rate on the left)
year_deaths = year_deaths.sort_values(ascending=False)

plt.figure(figsize=(6,4))
plt.bar(year_deaths.index, year_deaths.values)

plt.title('Members Deaths vs Year')
plt.xlabel('Year')
plt.ylabel('Members Deaths')
plt.show()

# %%
# Group by year and sum the number of members who summited
year_summits = expeditions_data.groupby('year')['mbrs_summited'].sum()

# Sort values (highest summit rate on the left)
year_summits = year_summits.sort_values(ascending=False)

plt.figure(figsize=(6,4))
plt.bar(year_summits.index, year_summits.values)

plt.title('Members Summited vs Year')
plt.xlabel('Year')
plt.ylabel('Members Summited')
plt.show()
